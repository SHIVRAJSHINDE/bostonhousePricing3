# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load the database
from sklearn.datasets import load_boston
boston = load_boston()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
dataset = pd.DataFrame(boston.data,columns=boston.feature_names)
dataset.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03

# %%
dataset.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
dataset['Price']=boston.target

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %% [markdown]
# # Exploratory Data Analysis
# # Correlation

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.scatter('CRIM','Price',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter('ZN','Price',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter('INDUS','Price',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter('CHAS','Price',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter('NOX','Price',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
features=dataset.columns

list(enumerate(features))
# Out:
# [(0, 'CRIM'),
#  (1, 'ZN'),
#  (2, 'INDUS'),
#  (3, 'CHAS'),
#  (4, 'NOX'),
#  (5, 'RM'),
#  (6, 'AGE'),
#  (7, 'DIS'),
#  (8, 'RAD'),
#  (9, 'TAX'),
#  (10, 'PTRATIO'),
#  (11, 'B'),
#  (12, 'LSTAT'),
#  (13, 'Price')]

# %%
plt.subplot(5,3,1)
plt.scatter('CHAS','Price',data=dataset)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.scatter('INDUS','Price',data=dataset)

plt.subplot(2,2,2)
plt.scatter('NOX','Price',data=dataset)

plt.subplot(2,2,3)
plt.scatter('NOX','Price',data=dataset)


plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.scatterplot('INDUS','Price',data=dataset)

plt.subplot(5,2,2)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,3)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,4)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,5)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,6)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,7)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,8)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,9)
sns.scatterplot('NOX','Price',data=dataset)

plt.subplot(5,2,10)
sns.scatterplot('NOX','Price',data=dataset)




plt.show()
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20,40))
for i in enumerate(features):
    plt.subplot(8,2,i[0]+1)
    sns.scatterplot(i[1],'Price',data=dataset)
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
dataset['AGE'].sort_values().unique()
# Out:
# array([  2.9,   6. ,   6.2,   6.5,   6.6,   6.8,   7.8,   8.4,   8.9,
#          9.8,   9.9,  10. ,  13. ,  13.9,  14.7,  15.3,  15.7,  15.8,
#         16.3,  17. ,  17.2,  17.5,  17.7,  17.8,  18.4,  18.5,  18.8,
#         19.1,  19.5,  20.1,  20.8,  21.1,  21.4,  21.5,  21.8,  21.9,
#         22.3,  22.9,  23.3,  23.4,  24.8,  25.8,  26.3,  27.6,  27.7,
#         27.9,  28.1,  28.4,  28.8,  28.9,  29.1,  29.2,  29.3,  29.7,
#         30.2,  30.8,  31.1,  31.3,  31.5,  31.9,  32. ,  32.1,  32.2,
#         32.3,  32.9,  33. ,  33.1,  33.2,  33.3,  33.5,  33.8,  34.1,
#         34.2,  34.5,  34.9,  35.7,  35.9,  36.1,  36.6,  36.8,  36.9,
#         37.2,  37.3,  37.8,  38.1,  38.3,  38.4,  38.5,  38.9,  39. ,
#         40. ,  40.1,  40.3,  40.4,  40.5,  41.1,  41.5,  41.9,  42.1,
#         42.2,  42.3,  42.4,  42.6,  42.8,  43.4,  43.7,  44.4,  45. ,
#         45.1,  45.4,  45.6,  45.7,  45.8,  46.3,  46.7,  47.2,  47.4,
# ...

# %%
dataset['AGE'].value_counts()
# Out:
# 100.0    43
# 96.0      4
# 98.2      4
# 95.4      4
# 97.9      4
#          ..
# 47.6      1
# 92.7      1
# 13.9      1
# 58.4      1
# 40.1      1
# Name: AGE, Length: 356, dtype: int64

# %%
sns.regplot('NOX','Price',data=dataset)
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NOX', ylabel='Price'>

# %%
plt.figure(figsize=(20,40))
for i in enumerate(features):
    plt.subplot(8,2,i[0]+1)
    sns.regplot(i[1],'Price',data=dataset)
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
X = dataset.iloc[:,:-1]

X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y = dataset.iloc[:,-1]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Price, Length: 506, dtype: float64

# %%
# Train test split

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
## Featrure Scaling
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
regression.coef_
# Out:
# array([-1.10834602,  0.80843998,  0.34313466,  0.81386426, -1.79804295,
#         2.913858  , -0.29893918, -2.94251148,  2.09419303, -1.44706731,
#        -2.05232232,  1.02375187, -3.88579002])

# %%
regression.intercept_
# Out:
# 23.01581920903956

# %%
## on which parameters the model has been trained

regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %%
## plot scatter plot for prediction

plt.scatter(y_test,reg_pred)

# %%
residual = (y_test-reg_pred)
residual
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: Price, Length: 152, dtype: float64

# %%
## Plotting the residuals

sns.displot(residual,kind='kde')

# %%
## scatter plot with respect to prediction and residuals

plt.scatter(reg_pred,residual)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(reg_pred,residual)
# Out:
# C:\Users\shind\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Price'>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 21.517444231177194
# 3.162709871457404
# 4.638689926172819

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
score
# Out:
# 0.7112260057484934

# %%
#display adjusted R-squared
#R2= 1-(1-R2)*((n-1)/(n-k-1))
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6840226584639312

# %%
boston.data[0].reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
## reshape the new data
value=boston.data[0].reshape(1,-1)
value
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
## Standardize the new data
value = scaler.transform(value)
value
# Out:
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
## after reshaping and standardizing then predict it
regression.predict(value)
# Out:
# array([30.08649576])

# %%
##Pickling the Model

# %%
import pickle
pickle.dump(regression,open('regmodel.pkl','wb'))
pickle_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickle_model.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# array([30.08649576])
